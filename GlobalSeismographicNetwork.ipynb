# %% [markdown]
# # Data Visualization - Global Seismographic Network
#
# ## Using [Folium](https://python-visualization.github.io/folium/)
#
# ![IRIS Logo](https://www.iris.edu/hq/images/layout/logos/iris_logo_shadow.png)
#
# #### Description
#
# The Global Seismographic Network (GSN) is a globally distributed, state-of-the-art digital seismic network that provides free, realtime, open access data through the IRIS DMC.  The map below shows the distribution of the current station network with respect to network operations. For more information check out the program at [IRIS](https://www.iris.edu/hq/programs/gsn "GSN program"). Station data is downloaded from [USGS](https://earthquake.usgs.gov/monitoring/operations/network.php?virtual_network=GSN "GSN stations").

# %%
# Import packages
import pandas as pd
import geopandas
import folium
# %matplotlib inline

# %% [markdown]
# #### How to read data from a webpage?
#
# Follow the instructions on [towards data science](https://towardsdatascience.com/all-pandas-read-html-you-should-know-for-scraping-data-from-html-tables-a3cbb5ce8274).

# %%
# Read data from webpage
url = "https://earthquake.usgs.gov/monitoring/operations/network.php?virtual_network=GSN"
dfs = pd.read_html(url)

print(f'Total tables: {len(dfs)}')
# Out:
# Total tables: 1

# %%
gsn = dfs[0]
gsn.head()
#print("Shape of dataframe: {}".format(gsn.shape))
# Out:
#   Network Code Station Code                                  Name Telemetry  \
# 0           CU         ANWB                  North Barbuda Island         –
# 1           CU         BBGH                    Gun Hill, Barbados         –
# 2           CU         BCIP           Isla Barro Colorado, Panama         –
# 3           CU         GRGR                    Grenville, Grenada         –
# 4           CU         GRTK  Grand Turk, Turks and Caicos Islands         –
#
#    Latitude  Longitude  Elevation
# 0    17.669    -61.786       39.0
# 1    13.143    -59.559      180.0
# 2     9.166    -79.837       61.0
# 3    12.132    -61.654      195.0
# 4    21.511    -71.133       12.0

# %%
# Convert Lat & Long into geometry using geopandas
gsn = geopandas.GeoDataFrame(
    gsn, geometry=geopandas.points_from_xy(gsn.Longitude, gsn.Latitude))

# Set Coordinate Reference System
gsn = gsn.set_crs("epsg:4326")

# %%
gsn
# Out:
#     Network Code Station Code                                     Name  \
# 0             CU         ANWB                     North Barbuda Island
# 1             CU         BBGH                       Gun Hill, Barbados
# 2             CU         BCIP              Isla Barro Colorado, Panama
# 3             CU         GRGR                       Grenville, Grenada
# 4             CU         GRTK     Grand Turk, Turks and Caicos Islands
# ..           ...          ...                                      ...
# 145           IU          WCI             Wyandotte Cave, Indiana, USA
# 146           IU          WVT                  Waverly, Tennessee, USA
# 147           IU         XMAS  Kiritimati Island, Republic of Kiribati
# 148           IU          YAK                          Yakutsk, Russia
# 149           IU          YSS                Yuzhno Sakhalinsk, Russia
#
#     Telemetry  Latitude  Longitude  Elevation                    geometry
# 0           –    17.669    -61.786       39.0  POINT (-61.78600 17.66900)
# 1           –    13.143    -59.559      180.0  POINT (-59.55900 13.14300)
# 2           –     9.166    -79.837       61.0   POINT (-79.83700 9.16600)
# 3           –    12.132    -61.654      195.0  POINT (-61.65400 12.13200)
# 4           –    21.511    -71.133       12.0  POINT (-71.13300 21.51100)
# ..        ...       ...        ...        ...                         ...
# 145         –    38.229    -86.294      210.0  POINT (-86.29400 38.22900)
# 146         –    36.130    -87.830      170.0  POINT (-87.83000 36.13000)
# 147         –     2.045   -157.446       19.0  POINT (-157.44600 2.04500)
# 148         –    62.031    129.680       96.0  POINT (129.68000 62.03100)
# 149         –    46.959    142.760      148.0  POINT (142.76000 46.95900)
#
# [150 rows x 8 columns]

# %% [markdown]
# According to [exploretrakaivilnius](https://exploretrakaivilnius.lt/en/manors-and-parks/the-geographical-centre-of-europe) the Geographical Centre of Europe is located at 54°50’45’’North – 25°18’23’’East.

# %%
# Create map
coordinates=[54.845833, 25.306389]
m = folium.Map(location=coordinates, zoom_start=1.5, tiles ='Stamen Terrain')

# %%
# Add locations with details
folium.GeoJson(
    gsn,
    tooltip=folium.GeoJsonTooltip(
        fields=['Network Code', 'Station Code', 'Name', 'Elevation'],
        aliases=['Network Code', 'Station Code', 'Name', 'Elevation']),
    popup=folium.GeoJsonPopup(
        fields=['Network Code', 'Station Code', 'Name', 'Elevation'],
        aliases=['Network Code', 'Station Code', 'Name', 'Elevation'])
).add_to(m)

# %%
# Name title
title = 'Global Seismographic Stations'
title_html = '''
             <h2 align="center" style="font-size:16px"><b>{}</b></h2>
             '''.format(title)

# %%
# Add title to map
m.get_root().html.add_child(folium.Element(title_html))

# %%
# Display map
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css%22/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_444ccc4ba3714c46b396c28a14876903%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20.foliumtooltip%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20.foliumtooltip%20table%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20margin%3A%20auto%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%2 ...

# %%
# Save map
m.save("output/GSNstations_HTMLmap.html")

# %% [markdown]
# #### Optional
#
# Try to apply Folium Marker Clusters to map following the approach by [deparkes](https://deparkes.co.uk/2016/06/24/folium-marker-clusters/ "Marker Cluster").
